# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.Read the dataset to the python environment

# %%
cars_data=pd.read_csv(r"C:\Users\HP\Downloads\cars_data.csv")

# %%
cars_data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %% [markdown]
# # 2.Check for the null values present in the dataset

# %%
cars_data.isna().any()
# Out:
# Make                 False
# Model                False
# Nickname             False
# Car Gender           False
# Buyer Gender         False
# Buyer Age            False
# Buzzword             False
# Country              False
# City                 False
# Dealer Latitude      False
# Dealer Longitude     False
# Color                False
# New Car              False
# Purchase Date        False
# Sale Price           False
# Discount             False
# Resell Price         False
# 5-yr Depreciation    False
# Top Speed            False
# 0-60 Time            False
# dtype: bool

# %% [markdown]
# So there is not any null values in the dataset

# %% [markdown]
# # 3.Plot a bar graph of male vs female buyers participated in the sales

# %%
gender_group=cars_data.groupby('Buyer Gender')

# %%
gender_group['Sale Price'].value_counts()
# Out:
# Buyer Gender  Sale Price
# Female        23810.58      2
#               10023.85      1
#               10024.86      1
#               10039.82      1
#               10040.40      1
#                            ..
# Male          99943.77      1
#               99973.44      1
#               99978.17      1
#               99983.38      1
#               99991.91      1
# Name: Sale Price, Length: 9997, dtype: int64

# %%
cars_data['Buyer Gender'].value_counts(normalize=True).plot(kind='bar',legend=True)
cars_data['Buyer Gender'].value_counts(normalize=True)
# Out:
# Female    0.5052
# Male      0.4948
# Name: Buyer Gender, dtype: float64

# %% [markdown]
# # 4.Find the top 5 cars based on their sales price

# %%
# first method
cars_data1=cars_data.sort_values('Sale Price',ascending=False)

# %%
cars_data1.head()
# Out:
#             Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen  Jetta III    Rachael     Female       Female         73
# 1270        Audi         A6      Thorn       Male         Male         75
# 3460       Lexus         LX      Aldin     Female         Male         38
# 9032       Mazda       MX-6  Sylvester     Female         Male         26
# 302        Lexus         ES       Brig     Female         Male         39
#
#                Buzzword   Country           City  Dealer Latitude  \
# 5984               core    Russia    Krasnoyarka        59.418208
# 1270           function    Latvia        Līgatne        57.236340
# 3460           software  Malaysia      Pasir Mas         6.109065
# 9032  internet solution    Russia  Krutaya Gorka        55.369917
# 302         user-facing    Canada       Langford        48.447463
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %% [markdown]
# So the top 5 cars on the basis of sale price are Volkswagen,Audi,Lexus,Mazda and Lexus

# %%
# second method
cars_data.nlargest(5,'Sale Price')[['Make','Sale Price','Model']]
# Out:
#             Make  Sale Price      Model
# 5984  Volkswagen    99997.65  Jetta III
# 1270        Audi    99991.91         A6
# 3460       Lexus    99983.38         LX
# 9032       Mazda    99978.17       MX-6
# 302        Lexus    99973.44         ES

# %% [markdown]
# # 5.Find the least 5 cars based on their resell price

# %%
# first method
cars_data2=cars_data.sort_values('Resell Price',ascending=True)

# %%
cars_data2.head()
# Out:
#             Make        Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 2446   Chevrolet         1500  Corenda       Male       Female         25
# 4933         GMC  Savana 1500     Lark     Female       Female         34
# 566       Jaguar           XF   Payton     Female         Male         64
# 2538  Mitsubishi       3000GT     Thia     Female       Female         25
# 5869    Infiniti          G37    Sonny       Male         Male         20
#
#             Buzzword      Country              City  Dealer Latitude  \
# 2446   collaboration  Philippines           Tubigan         8.490877
# 4933     interactive       Poland       Śródmieście        53.838651
# 566        Visionary      Nigeria       Ikot-Ekpene         5.174447
# 2538  well-modulated        China        Yanweigang        34.509325
# 5869      optimizing       France  Clermont-Ferrand        45.786764
#
#       Dealer Longitude      Color  New Car Purchase Date  Sale Price  \
# ...

# %%
# second method
cars_data.nsmallest(5,'Resell Price')[['Make','Resell Price','Model']]
# Out:
#             Make  Resell Price        Model
# 2446   Chevrolet       2000.84         1500
# 4933         GMC       2005.44  Savana 1500
# 566       Jaguar       2014.09           XF
# 2538  Mitsubishi       2017.24       3000GT
# 5869    Infiniti       2017.83          G37

# %% [markdown]
# So the least 5 cars on the basis of resell price are Chevrolet,GMC,Jaguar,Mitsubishi and Infiniti
